# %% [markdown]
# # Image Caption generation

# %% [markdown]
# ### Execution Instruction
#
# Please download the model weights from this [Google Drive URL](https://drive.google.com/drive/folders/1aDVI8e_xPu07rxpRalF89pWn91Pmet4v?usp=share_link).
# Then, replace the existing "model_weights" folder with your downloaded folder that contains 2 weights files.
#
# There are a selection of images in the "examples" folder for illustration. Feel free to add/replace your own images to this folder.

# %%
# %cd src
# Out:
# /Users/jackyu/Developer/CS-175-Image-Caption/src

# %%
from eval import experiment
image_folder = "../examples"
dataset = "8K"  # you can change this to 30K to load the different weights
experiment(image_folder, dataset)
# Out:
# ../examples/IMG_3124.jpg :
# Man is standing in the sand next to the ocean.
#
# ../examples/IMG_2980.jpg :
# Group of people are watching the field.
#
# ../examples/IMG_3097.jpg :
# The man is running through the blue and black and white uniform.
#
# ../examples/972381743.jpg :
# Woman in pink and black outfit and black outfit.
#
# ../examples/96973080.jpg :
# Dog running through the snow.
#
# ../examples/IMG_1226.jpeg :
# Man in blue shirt is sitting on the background.
#
# ../examples/97233789.jpg :
# Man in blue shirt is standing on the background.
#
# ../examples/952171414_2db16f846f.jpg :
# Two people are standing on the street.

# %% [markdown]
# Now, the images and their captions are saved in the "figs" folder. Have fun!

# %% [markdown]
# ## Appendix

# %% [markdown]
# If you also want to run the training algorithm (training.ipynb) inside the "src" folder, download this [Flickr 8K dataset](https://www.kaggle.com/datasets/adityajn105/flickr8k) and/or [Flickr 30K dataset](https://www.kaggle.com/datasets/adityajn105/flickr30k). Unzip them, and replace the Images folders:
# -      data
# -       * flickr8k
# -           - Images
# or
# -      data
# -       * flickr30k
# -           - Images
#
# with the unzipped folder by the same name.
#
# Then, run all the cells within training.ipynb
